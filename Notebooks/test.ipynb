# %%
import numpy as np
np.linspace(-1, 1, 2)
# Out:
# array([-1.,  1.])

# %%
from qlora_presentation.visualisation.styles import Style


style = Style()

# %%
style.background
# Out:
# Colour(primary=ManimColor('#000000'), secondary=ManimColor('#212121'), tertiary=ManimColor('#424242'))

# %%
from qlora_presentation.visualisation.styles import FontWeight


a = FontWeight.BOLD
print((a))
print(str(a))
# Out:
# BOLD
# BOLD
